# %% [markdown]
# <a href="https://colab.research.google.com/github/ParhamPishro/Flavonoid/blob/main/1%20Data%20Collection/Characteristics_of_the_Included_Studies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
#Read Data

df = pd.read_excel("/content/TrainTest.xlsx")
df
# Out:
#                   authors  flavonoid cell line  time  dose  viability-mean  \
# 0        Chen et al. 2017   Luteolin    KYSE30    48  10.0       77.272727
# 1        Chen et al. 2017   Luteolin    KYSE30    48  20.0       67.613636
# 2        Chen et al. 2017   Luteolin    KYSE30    48  40.0       47.159091
# 3        Chen et al. 2017   Luteolin    KYSE30    48  80.0       32.386364
# 4        Chen et al. 2017   Luteolin    KYSE30    72  10.0       69.886364
# ..                    ...        ...       ...   ...   ...             ...
# 582  Wang et al. 2011 (2)  Baicalein      OE33    48  80.0       48.551895
# 583  Wang et al. 2011 (2)  Baicalein      OE33    72  10.0       82.833608
# 584  Wang et al. 2011 (2)  Baicalein      OE33    72  20.0       71.960461
# 585  Wang et al. 2011 (2)  Baicalein      OE33    72  40.0       49.540362
# 586  Wang et al. 2011 (2)  Baicalein      OE33    72  80.0       48.237232
#
#      viability-error  viability-SD  viability-SE
# ...

# %%
# 1st, 2nd, and 3rd Column

df[['authors', 'flavonoid', 'cell line']].groupby(['authors', 'flavonoid', 'cell line']).size()
# Out:
# authors                flavonoid   cell line
# Chen et al. 2017       Luteolin    KYSE30        8
#                                    KYSE450       8
# Chen et al. 2021       Chrysin     KYSE150       4
#                                    KYSE30        5
#                                    KYSE410       5
#                                    KYSE450       5
#                                    YES2          5
# Guo et al. 2022        Baicalein   KYSE150       4
# Jia et al. 2021        Cirsiliol   KYSE140       9
#                                    KYSE450       9
# Li et al. 2023         Quercetin   KYSE150       4
#                                    KYSE30        4
# Qiao et al. 2018       Casticin    TE-1         18
# Qin et al. 2021        Luteolin    TE-1         24
# Qiu et al. 2019        Apigenin    KYSE30        5
# Ren et al. 2016        Galangin    TE-1          7
# Wang and Renquan 2023  Acacetin    TE-1          9
# ...

# %%
# 4th Column (min)

df[['authors', 'dose']].groupby(['authors']).min()
# Out:
#                        dose
# authors
# Chen et al. 2017       10.0
# Chen et al. 2021        1.0
# Guo et al. 2022         6.7
# Jia et al. 2021         5.0
# Li et al. 2023         50.0
# Qiao et al. 2018        1.0
# Qin et al. 2021        10.0
# Qiu et al. 2019         3.0
# Ren et al. 2016         2.5
# Wang and Renquan 2023  20.0
# Wang and Zheng 2016    10.0
# Wang et al. 2011       10.0
# Wang et al. 2011 (2)   10.0
# Wang et al. 2018        2.5
# Xie et al 2018         20.0
# Xin 2008               10.0
# Yao et al. 2016        15.0
# Zang et al. 2014       20.0
# Zhang et al. 2008      10.0
# Zhang et al. 2009      10.0
# Zhang et al. 2021      10.0
# Zhu et al. 2016        20.0

# %%
# 4th Column (max)

df[['authors', 'dose']].groupby(['authors']).max()
# Out:
#                         dose
# authors
# Chen et al. 2017        80.0
# Chen et al. 2021        50.0
# Guo et al. 2022         20.0
# Jia et al. 2021         20.0
# Li et al. 2023         200.0
# Qiao et al. 2018        40.0
# Qin et al. 2021        160.0
# Qiu et al. 2019        300.0
# Ren et al. 2016         50.0
# Wang and Renquan 2023   60.0
# Wang and Zheng 2016    100.0
# Wang et al. 2011        80.0
# Wang et al. 2011 (2)    80.0
# Wang et al. 2018        50.0
# Xie et al 2018          60.0
# Xin 2008                80.0
# Yao et al. 2016         60.0
# Zang et al. 2014        40.0
# Zhang et al. 2008       80.0
# Zhang et al. 2009       80.0
# Zhang et al. 2021       80.0
# Zhu et al. 2016        100.0

# %%
# 5th Column

df[['authors', 'time']].groupby(['authors','time']).size()
# Out:
# authors                time
# Chen et al. 2017       48       8
#                        72       8
# Chen et al. 2021       72      24
# Guo et al. 2022        24       2
#                        48       2
# Jia et al. 2021        24       6
#                        48       6
#                        72       6
# Li et al. 2023         48       8
# Qiao et al. 2018       24       6
#                        48       6
#                        72       6
# Qin et al. 2021        24       8
#                        48       8
#                        72       8
# Qiu et al. 2019        48       5
# Ren et al. 2016        48       7
# Wang and Renquan 2023  24       6
#                        48       6
#                        72       6
# Wang and Zheng 2016    24       4
#                        48       5
#                        72       6
# Wang et al. 2011       24      14
#                        48      16
#                        72      16
# ...

# %%
# Last Column

df[['authors']].groupby(['authors']).size()
# Out:
# authors
# Chen et al. 2017          16
# Chen et al. 2021          24
# Guo et al. 2022            4
# Jia et al. 2021           18
# Li et al. 2023             8
# Qiao et al. 2018          18
# Qin et al. 2021           24
# Qiu et al. 2019            5
# Ren et al. 2016            7
# Wang and Renquan 2023     18
# Wang and Zheng 2016       15
# Wang et al. 2011          46
# Wang et al. 2011 (2)      43
# Wang et al. 2018          30
# Xie et al 2018             9
# Xin 2008                 137
# Yao et al. 2016            8
# Zang et al. 2014           6
# Zhang et al. 2008         71
# Zhang et al. 2009         67
# Zhang et al. 2021          8
# Zhu et al. 2016            5
# dtype: int64
