# %% [markdown]
# <a href="https://colab.research.google.com/github/ParhamPishro/Flavone/blob/main/3%20Exploratory%20Data%20Analysis%20and%20Data%20Visualization/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Read Data

# %%
df = pd.read_excel("/content/FlavoneData.xlsx")
df
# Out:
#                    authors   flavone cell line  time   dose  viability-mean  \
# 0    Wang and Renquan 2023  Acacetin      TE 1    24   20.0       90.247253
# 1    Wang and Renquan 2023  Acacetin      TE 1    24   40.0       81.593407
# 2    Wang and Renquan 2023  Acacetin      TE 1    24   60.0       42.857143
# 3    Wang and Renquan 2023  Acacetin      TE 1    48   20.0       76.648352
# 4    Wang and Renquan 2023  Acacetin      TE 1    48   40.0       63.049451
# ..                     ...       ...       ...   ...    ...             ...
# 466        Liu et al. 2017  Luteolin    EC 109    24  100.0       55.459459
# 467        Liu et al. 2017  Luteolin  KYSE 150    24   10.0       96.000000
# 468        Liu et al. 2017  Luteolin  KYSE 150    24   20.0       86.270270
# 469        Liu et al. 2017  Luteolin  KYSE 150    24   50.0       77.837838
# 470        Liu et al. 2017  Luteolin  KYSE 150    24  100.0       60.000000
#
#      viability-error  viability-SD  viability-SE
# ...

# %% [markdown]
# Discretized Data

# %%
df['v01'] = 1
df.loc[df['viability-mean']>50, 'v01'] = 0

# %%
df = df.drop(['authors', 'viability-error', 'viability-SD', 'viability-SE'], axis=1)
df
# Out:
#       flavone cell line  time   dose  viability-mean  v01
# 0    Acacetin      TE 1    24   20.0       90.247253    0
# 1    Acacetin      TE 1    24   40.0       81.593407    0
# 2    Acacetin      TE 1    24   60.0       42.857143    1
# 3    Acacetin      TE 1    48   20.0       76.648352    0
# 4    Acacetin      TE 1    48   40.0       63.049451    0
# ..        ...       ...   ...    ...             ...  ...
# 466  Luteolin    EC 109    24  100.0       55.459459    0
# 467  Luteolin  KYSE 150    24   10.0       96.000000    0
# 468  Luteolin  KYSE 150    24   20.0       86.270270    0
# 469  Luteolin  KYSE 150    24   50.0       77.837838    0
# 470  Luteolin  KYSE 150    24  100.0       60.000000    0
#
# [471 rows x 6 columns]

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
df.describe().T
# Out:
#                 count       mean        std        min        25%        50%  \
# time            471.0  48.713376  19.913873  24.000000  24.000000  48.000000
# dose            471.0  44.152335  45.081349   0.300000  10.000000  30.000000
# viability-mean  471.0  59.653128  25.345455   0.930233  42.302158  63.823529
# v01             471.0   0.337580   0.473387   0.000000   0.000000   0.000000
#
#                       75%         max
# time            72.000000   96.000000
# dose            60.000000  300.000000
# viability-mean  79.131038  107.482014
# v01              1.000000    1.000000
